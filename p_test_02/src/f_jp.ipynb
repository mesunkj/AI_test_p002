# %%
import os 
HUGGINGFACEHUB_API_TOKEN = "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"
os.environ["HUGGINGFACEHUB_API_TOKEN"] = HUGGINGFACEHUB_API_TOKEN
f'var "HUGGINGFACEHUB_API_TOKEN" in os is {"HUGGINGFACEHUB_API_TOKEN" in os.environ}'

# %%
# ! pip install huggingface_hub

# %%
from huggingface_hub import InferenceClient

client = InferenceClient(
    provider="hf-inference",
    token="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"
)

image = client.text_to_image(
    "A full-body portrait of a young Asian woman standing barefoot on green grass in a mountain valley, wearing a navy blue one-piece swimsuit, soft natural lighting, photo-realistic skin texture, sunlight on face, long dark brown ponytail, calm expression, cinematic depth of field, ultra detailed, sharp focus, 4K resolution\
",
    negative_prompt="blurry, cartoon, anime, drawing, painting, deformed, extra limbs, bad anatomy, low quality, overexposed, underexposed, watermark\
",
    model="SG161222/Realistic_Vision_V6.0_B1_noVAE",
)
id_ = '003'
image.save(f"pic_{id_}.png")

# %%
# ! pip install requests

# %%
from huggingface_hub import InferenceClient
# import requests
# from PIL import Image
# from io import BytesIO

# 選擇寫實模型：我們這裡用 Hugging Face 的 Stable Diffusion Space
# client = InferenceClient(model="stabilityai/stable-diffusion")
client = InferenceClient(
    provider="hf-inference",
    token="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"
)
# 建立 prompt
prompt = (
    "A full-body portrait of a young Asian woman standing barefoot on green grass in a mountain valley, "
    "wearing a navy blue one-piece swimsuit, soft natural lighting, photo-realistic skin texture, "
    "sunlight on face, long dark brown ponytail, calm expression, cinematic depth of field, ultra detailed, sharp focus, 4K resolution"
)

negative_prompt = (
    "blurry, cartoon, anime, drawing, painting, deformed, extra limbs, bad anatomy, low quality, overexposed, underexposed, watermark"
)

# 產生圖片
image = client.text_to_image(
    prompt=prompt,
    negative_prompt=negative_prompt,
    guidance_scale=7.5,
    num_inference_steps=30,
    # model="SG161222/Realistic_Vision_V6.0_B1_noVAE",
    model="stabilityai/stable-diffusion-3.5-large"
)
id_ = '004'
image.save(f"../output/pic_{id_}.png")

# 顯示圖片
# image = Image.open(BytesIO(image_bytes))
image.show()

# %% [markdown]
# multi-thread

# %%
# ✅ 50組不同的 prompt（可以根據需要修改）
PROMPTS = [
    "A young woman wearing a red dress, standing by a beautiful river during sunset, photorealistic",
    "A woman in a blue gown, sitting on a chair in a luxurious living room, soft lighting",
    "A model in a white dress, posing on a tropical beach at sunrise, the wind blowing through her hair",
    "A confident businesswoman in a modern office, wearing a sharp suit and glasses",
    "A teenage girl with long, curly hair, smiling as she runs through a field of flowers",
    "A female athlete in running gear, sprinting on an empty track, determined expression",
    "A girl wearing a school uniform, reading a book under a tree in a park",
    "A woman in a leather jacket, walking through a busy street at night, neon lights in the background",
    "A model posing in a fashion studio, wearing a chic black dress, with dramatic lighting",
    "A woman holding a large bouquet of flowers in a greenhouse, soft and natural light",
    "A girl with braided hair, sitting on a mountain top with a scenic view of the valley",
    "A woman in a casual outfit, enjoying a coffee at a café by the window, warm ambiance",
    "A female chef preparing a gourmet dish in a modern kitchen, wearing a white apron",
    "A woman in a bikini, standing on a sandy beach with the ocean in the background",
    "A woman in a cozy sweater, knitting by the fireplace in a cabin, relaxing atmosphere",
    "A young model with a stylish haircut, striking a pose on the runway during a fashion show",
    "A woman wearing a floral dress, walking through a garden full of colorful flowers",
    "A girl in a white summer dress, spinning around in a field of tall grass under a clear blue sky",
    "A female photographer capturing portraits of models in an outdoor studio",
    "A woman with a confident expression, standing tall on a rooftop overlooking the city",
    "A girl in a traditional dress, walking through a lively market in an exotic location",
    "A woman in a business suit, presenting a report in a high-rise conference room",
    "A female dancer practicing ballet in an elegant studio with large mirrors",
    "A girl in a leather jacket, riding a bicycle down a winding country road",
    "A woman sitting on a bench in a park, reading a book, with autumn leaves falling around her",
    "A woman in a red carpet gown, smiling for the cameras at a glamorous event",
    "A young woman holding an umbrella, walking through the rain in a city street",
    "A female fashion model in a stylish outfit, posing on a rooftop at sunset",
    "A woman in a red sweater, enjoying hot cocoa in a cozy cabin in the mountains",
    "A girl with bright eyes, sitting on a swing in a park, looking up at the sky",
    "A woman in a black dress, attending a formal dinner in an upscale restaurant",
    "A female surfer catching a wave at dawn, the ocean glowing in the early morning light",
    "A girl with freckles, sitting on a grassy hillside, gazing at the clouds",
    "A woman in a winter coat, walking through a snowy forest with a serene expression",
    "A female architect sketching plans at her desk in a modern office building",
    "A girl wearing a hoodie, laughing while walking through the streets at night",
    "A woman in a silk robe, gazing out a large window at a city skyline",
    "A female mountain climber standing triumphantly at the summit, wind blowing her hair",
    "A model in an evening gown, walking down the staircase at a luxurious ballroom",
    "A woman in a black leather dress, leaning against a motorcycle in a dark alley",
    "A girl wearing glasses, sitting in a library reading a thick book",
    "A woman in a long flowing dress, standing on a cliff, looking at the sunset over the ocean",
    "A female singer on stage, holding a microphone, with spotlight shining on her",
    "A woman with curly hair, sitting on a porch swing, enjoying a warm summer evening",
    "A young woman in a red plaid shirt, sitting by the fire pit in the backyard",
    "A woman in a business outfit, standing confidently in a crowded city street",
    "A girl with a flower crown, dancing barefoot in a meadow during golden hour",
    "A model posing in a luxurious fur coat, walking through a snow-covered street",
    "A woman in a pastel-colored dress, walking barefoot on a sandy beach at dusk",
    "A girl in a long coat, walking through a busy shopping street, holding shopping bags",
    "A woman in a fitted blazer, smiling as she walks through a city park",
    "A female gymnast performing a split in a sports arena, athletic and graceful",
    "A young woman in a denim jacket, walking through a rustic town square on a sunny day",
    "A girl in a pink dress, playing with puppies in a sunny backyard",
    "A woman with a headscarf, walking through an ancient temple with sunlight filtering through",
    "A model wearing a futuristic outfit, standing against a dark, moody backdrop in a studio",
    "A woman sitting on a boat, gazing at the stars above a calm lake at night",
    "A female artist painting on a canvas in a sunlit studio, surrounded by brushes and paints",
    "A woman in a white blouse, standing by a vintage car, with the wind in her hair",
    "A girl wearing a colorful scarf, looking out from a balcony with a view of the city",
    "A female traveler with a backpack, hiking up a mountain trail, taking in the view"
]

# 負面 prompt（可自訂）
NEGATIVE_PROMPT = "cartoon, anime, drawing, blurry, bad anatomy, extra limbs, watermark"

# %%
from huggingface_hub import InferenceClient
import os
import time
from concurrent.futures import ThreadPoolExecutor, as_completed

# 初始化 InferenceClient，指定 Hugging Face 提供者和 Token
client = InferenceClient(
    provider="hf-inference",
    token="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"  # 用你的 Hugging Face Token 替換
)

# 圖片儲存資料夾
OUTPUT_DIR = "../output_images"
os.makedirs(OUTPUT_DIR, exist_ok=True)



# ✅ 使用 `InferenceClient` 生成單張圖片
def generate_image(prompt: str, index: int) -> str:
    print(f"[{index}] Sending request: {prompt[:40]}...")

    # 使用 `InferenceClient` 進行推理
    image = client.text_to_image(
        prompt=prompt,
        negative_prompt=NEGATIVE_PROMPT,
        width=768,
        height=512,
        num_inference_steps=30,
        guidance_scale=7.5,
        model="stabilityai/stable-diffusion-3.5-large"

    )

    # 儲存圖片
    id_ = f'_{index}'
    filename = f"../output_images/pic_{id_}.png"
    image.save(filename)
    
    print(f"[{index}] Image saved: {filename}")
    return filename

# ✅ 批次並行處理
def generate_batch(prompts: list, max_workers=3):
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = []
        for idx, prompt in enumerate(prompts):
            futures.append(executor.submit(generate_image, prompt, idx))

        for future in as_completed(futures):
            _ = future.result()
    print("done")  # 所有任務完成後印出

# ✅ 主程式
# if __name__ == "__main__":
#     generate_batch(PROMPTS, max_workers=3)


generate_batch(PROMPTS, max_workers=3)
